# %% [markdown]
# # **Data From Web Scraping**
#
# The objective will be scraping the most information for each film in different top 100 lists from [Imdb](https://www.imdb.com/?ref_=nv_home). For example, in [The Top 100 Greatest Movies of all Time](https://www.imdb.com/list/ls055592025/) there are listed 100 films, from here it will be necessary to to access each film web page, once there, it can be found all the information about the film.
#
# - The top lists selected for this exercise are:
#
#     1. [The Top 100 Greatest Movies of all Time](https://www.imdb.com/list/ls055592025/)
#     2. [Top 100 Horror Films](https://www.imdb.com/list/ls000007562/)
#     3. [100 Best Sci-Fi movies](https://www.imdb.com/list/ls009668082/)
#     4. [Top 100 Best Action Movies Of All Time](https://www.imdb.com/list/ls063897780/)
#     5. [TOP 100 BEST DRAMA MOVIES OF ALL TIME](https://www.imdb.com/list/ls069376839/)
#     6. [Top 100 Best Foreign Films](https://www.imdb.com/list/ls062615147/)
#     7. [100 Best Movies of this Decade (2010-2019)](https://www.imdb.com/list/ls062615147/)
#     8. [2000s Top 100 Movies](https://www.imdb.com/list/ls002065120/)
#
# From a quick view of the page of a [film](https://www.imdb.com/title/tt0078748/?ref_=ttls_li_tt), the information selected to be obatined is listed below:
#
# 1. **`Top`** : Top list in which the film appears (str)
# 2. **`Ranking`** : Rank in which he movie appears (int)
# 3. **`Title`** : Title of the film (str)
# 4. **`Classification`**: Classificaion of the film (str)
# 5. **`Duration_min`**: Length of the film in minutes (int)
# 6. **`Genre(s)`**: Genre(s) of the film (str)
# 7. **`Imdb_Rating`**: Imdb of the film (float)
# 8. **`No_Ratings`**: Number of ratings (int)
# 9. **`Release_Date`**: Release date of the film (datetime)
# 10. **`Summary`**: Summary of the film (str)
# 11. **`Storyline`**: Storyline of the film (str)
# 12. **`Metascore`**: Metacritic score of the film (int)
# 13. **`User_reviews`**: Number of user reviews (int)
# 14. **`Critic_reviews`**: Number of critic reviews (int)
# 15. **`Popularity`**: Popularity rank (int)
# 16. **`Cast`**: Main Cast of the film (dict)
# 17. **`Taglines`**: Taglines of the film (str)
# 18. **`Country`**: Country of Origin (str)
# 19. **`Budget`**: Budget of the film (str)
# 21. **`Cumulative_Worldwide_Gross`**: Grossing revenue of the film (str)
# 22. **`Trivia`**: Trivia of the film (str)
# 23. **`Goof`**: A goof find in the movie (str)
#
# Namely, the final dataframe (an the csv file) will have the above as columns.

# %% [markdown]
# First, the necessary libraries are imported:

# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import matplotlib.style as style
style.use('seaborn-darkgrid')

# %%
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# Next is to create two functions, `get_top_films` and `get_movie_info`.
#
# - **`get_top_films`**: this function will take one argument, the top list link; with this the web page will be scrapped in order to obtain the rank, title and the film web page reference. The result will be a list of tuples, one tuple for each movie listed.
# - **`get_movie_info`**: this function wil take two arguments, the base url and the movie info. The base url is a common url template shared by all movies web pages, the diference lies in the film reference number, which will be passed with a string concatenation. The movie info will be received by the function in the form of a tuple, which will contain in order the top list name in which the movie appears, the rank of the movie in the top list and the title of the movie. The result will be a list containing all the information of the movie required.

# %%
def get_top_films(top):
    # Scraping the films with rank, title and web reference
    parsed_top = BeautifulSoup(requests.get(tops_imdb[top], verify = False).content)
    return [(top, rank, title.next_sibling.next_sibling.text, title.next_sibling.next_sibling['href']) 
            for rank,title in enumerate(parsed_top.find_all('span',{'class':'lister-item-index unbold text-primary'}), 1)]

# %%
def get_movie_info(base, title):
    # Print progress
    clear_output()
    print(f'{title[0]} - {title[2]} - {title[1]}')
    
    # Technical movie data base url
    tech = 'https://www.imdb.com/%s/technical?ref_=tt_dt_spec'
    
    # Parsing the webpage of the given title
    parsed_title = BeautifulSoup(requests.get(base % title[3][1:-1], verify = False).content)
    
    # Each data requires a specific search in the parsed webpage
    top = title[0]
    ranking = title[1]
    title_film = parsed_title.find('div', class_='originalTitle').text.split(' (')[0] if parsed_title.find('div', class_='originalTitle') else title[2]
    classification = parsed_title.find_all('div', class_='subtext')[0].text.split('\n')[1].replace(' ','')
    length = BeautifulSoup(requests.get(tech % gm[26][3][1:-1], verify = False).content).select_one('.label').next_sibling.next_sibling.text.split('\n ')[1].lstrip().rstrip()
    genre = ', '.join(set([i.text.replace(' ','') for i in parsed_title.select("a[href*=genres]")]))
    imdb_rating = float(parsed_title.find('div', class_='ratingValue').text.split('/')[0][1:])
    ratings = int(parsed_title.find('span', class_='small').text.replace(',',''))
    release = pd.to_datetime(''.join([i.next_sibling for i in parsed_title.find_all('h4', class_='inline') if 'Release' in i.text]).split(' (')[0])
    summary = parsed_title.find('div', class_='summary_text').text.replace('\n','').rstrip().lstrip()
    storyline = parsed_title.find('div', class_='inline canwrap').text.split('\n')[2].lstrip()
    metascore = int(parsed_title.select_one('.metacriticScore').text.replace('\n','')) if parsed_title.select_one('.metacriticScore') else ''
    u_reviews = int(re.findall(r'\d+(?:,\d+)?', ''.join([i.text.replace(',','') for i in parsed_title.find_all('span', class_='subText')]))[0]) if len(parsed_title.find_all('span', class_='subText'))>=1 else ''
    c_reviews = int(re.findall(r'\d+(?:,\d+)?', ''.join([i.text.replace(',','') for i in parsed_title.find_all('span', class_='subText')]))[1]) if len(parsed_title.find_all('span', class_='subText'))!=1 else ''
    popularity = int(parsed_title.find_all('span', class_='subText')[-1].text.replace('\n','').replace(',','').lstrip().split()[0])
    cast = {pair[0]:('' if len(pair)==1 else pair[1].split('2 e')[0].replace('/','').rstrip().replace('\xa0','')) for pair in [i.text.replace('\n','').replace('  ','').split('...') for i in parsed_title.find_all('tr')[1:-2][0::2]]}
    tagline = parsed_title.find_all('h4', class_='inline')[4].next_sibling[1:]
    country = ' / '.join([c.text for c in parsed_title.find_all('div', class_='txt-block')[4].find_all('a')])
    budget = ''.join([i.next_sibling for i in parsed_title.find_all('h4', class_='inline') if 'Budget' in i.text]).replace('\n','').replace(' ','')
    cwg = ''.join([i.next_sibling for i in parsed_title.find_all('h4', class_='inline') if 'Cumulative' in i.text]).replace('\n','').replace(' ','')
    trivia = parsed_title.find('div', {'id':'trivia'}).text.split('    ')[1] if parsed_title.find('div', {'id':'trivia'}) else ''
    goof = parsed_title.find('div', {'id':'goofs'}).text.split('\n')[2].split('   ')[0] if parsed_title.find('div', {'id':'goofs'}) else ''
    
    return [top,ranking, title_film, classification, length,genre, imdb_rating, metascore, ratings, release, summary, storyline, u_reviews, c_reviews, popularity, cast,tagline, country, budget, cwg, trivia, goof]

# %% [markdown]
# The links of the top lists are stored in the `tops_imdb` dictionary.

# %%
tops_imdb = {'The Top 100 Greatest Movies of all Time':'https://www.imdb.com/list/ls055592025/',
             'Top 100 Horror Films':'https://www.imdb.com/list/ls000007562/',
             '100 Best Sci-Fi movies':'https://www.imdb.com/list/ls009668082/',
             'Top 100 Best Action Movies Of All Time':'https://www.imdb.com/list/ls063897780/',
             'TOP 100 BEST DRAMA MOVIES OF ALL TIME':'https://www.imdb.com/list/ls069376839/',
             'Top 100 Best Foreign Films':'https://www.imdb.com/list/ls062615147/',
             '100 Best Movies of this Decade (2010-2019)':'https://www.imdb.com/list/ls062615147/',
             '2000s Top 100 Movies':'https://www.imdb.com/list/ls002065120/'}

# %% [markdown]
# The `base_url` string varible will contain the url template.

# %%
base_url = 'https://www.imdb.com/%s/?ref_=ttls_li_tt'

# %% [markdown]
# Having crated all the variables and functions before, only rest to call for them in order to scrape all the 800 web pages. This is made in the line of code below:

# %%
movies_info = [get_movie_info(base_url, film) for film in [title for top in [get_top_films(key) for key in list(tops_imdb.keys())] for title in top]]
# Out:
# 2000s Top 100 Movies - El desesperar de los muertos - 100

# %% [markdown]
# The names for the dataframe are defined in the `names` list.

# %%
names = ['Top', 'Ranking', 'Title', 'Classification', 'Length', 'Genre', 'Imdb_Rating', 'Metascore', 'No_Ratings', 'Release_Date', 'Summary', 'Storyline', 'User_reviews', 
         'Critic_reviews', 'Popularity', 'Cast', 'Taglines', 'Country', 'Budget', 'Cumulative_Worldwide_Gross', 'Trivia', 'Goof']

# %% [markdown]
# The `movies_df` dataframe is created using the `from_records` method, wich is more suitable for the data that is in the form of a list of lists.

# %%
movies_df = pd.DataFrame.from_records(movies_info, columns = names)

# %%
movies_df.head(50)
# Out:
#                                         Top  Ranking  \
# 0   The Top 100 Greatest Movies of all Time        1
# 1   The Top 100 Greatest Movies of all Time        2
# 2   The Top 100 Greatest Movies of all Time        3
# 3   The Top 100 Greatest Movies of all Time        4
# 4   The Top 100 Greatest Movies of all Time        5
# 5   The Top 100 Greatest Movies of all Time        6
# 6   The Top 100 Greatest Movies of all Time        7
# 7   The Top 100 Greatest Movies of all Time        8
# 8   The Top 100 Greatest Movies of all Time        9
# 9   The Top 100 Greatest Movies of all Time       10
# 10  The Top 100 Greatest Movies of all Time       11
# 11  The Top 100 Greatest Movies of all Time       12
# 12  The Top 100 Greatest Movies of all Time       13
# 13  The Top 100 Greatest Movies of all Time       14
# 14  The Top 100 Greatest Movies of all Time       15
# 15  The Top 100 Greatest Movies of all Time       16
# 16  The Top 100 Greatest Movies of all Time       17
# 17  The Top 100 Greatest Movies of all Time       18
# 18  The Top 100 Greatest Movies of all Time       19
# 19  The Top 100 Greatest Movies of all Time       20
# 20  The Top 100 Greatest Movies of all Time       21
# 21  The Top 100 Greatest Movies of all Time       22
# 22  The Top 100 Greatest Movies of all Time       23
# 23  The Top 100 Greatest Movies of all Time       24
# 24  The Top 100 Greatest Movies of all Time       25
# 25  The Top 100 Greatest Movies of all Time       26
# 26  The Top 100 Greatest Movies of all Time       27
# 27  The Top 100 Greatest Movies of all Time       28
# 28  The Top 100 Greatest Movies of all Time       29
# 29  The Top 100 Greatest Movies of all Time       30
# 30  The Top 100 Greatest Movies of all Time       31
# 31  The Top 100 Greatest Movies of all Time       32
# 32  The Top 100 Greatest Movies of all Time       33
# 33  The Top 100 Greatest Movies of all Time       34
# 34  The Top 100 Greatest Movies of all Time       35
# 35  The Top 100 Greatest Movies of all Time       36
# 36  The Top 100 Greatest Movies of all Time       37
# 37  The Top 100 Greatest Movies of all Time       38
# 38  The Top 100 Greatest Movies of all Time       39
# 39  The Top 100 Greatest Movies of all Time       40
# 40  The Top 100 Greatest Movies of all Time       41
# 41  The Top 100 Greatest Movies of all Time       42
# 42  The Top 100 Greatest Movies of all Time       43
# 43  The Top 100 Greatest Movies of all Time       44
# 44  The Top 100 Greatest Movies of all Time       45
# 45  The Top 100 Greatest Movies of all Time       46
# 46  The Top 100 Greatest Movies of all Time       47
# 47  The Top 100 Greatest Movies of all Time       48
# 48  The Top 100 Greatest Movies of all Time       49
# 49  The Top 100 Greatest Movies of all Time       50
#
#                                                 Title Classification  \
# 0                                       The Godfather              C
# 1                            The Shawshank Redemption              B
# 2                                    Schindler's List            B15
# 3                                         Raging Bull              C
# 4                                          Casablanca              B
# 5                                        Citizen Kane             PG
# 6                                  Gone with the Wind              B
# 7                                    The Wizard of Oz              A
# 8                     One Flew Over the Cuckoo's Nest
# 9                                  Lawrence of Arabia              B
# 10                                            Vertigo             PG
# 11                                             Psycho              R
# 12                             The Godfather: Part II
# 13                                  On the Waterfront              A
# 14                                       Sunset Blvd.
# 15                                       Forrest Gump          PG-13
# 16                                 The Sound of Music
# 17                                       12 Angry Men              B
# 18                                    West Side Story
# 19                                          Star Wars             AA
# 20                              2001: A Space Odyssey              B
# 21                         E.T. the Extra-Terrestrial              A
# 22                           The Silence of the Lambs              C
# 23                                          Chinatown            B15
# 24                       The Bridge on the River Kwai             PG
# 25                                Singin' in the Rain              G
# 26                              It's a Wonderful Life             PG
# 27  Dr. Strangelove or: How I Learned to Stop Worr...              A
# 28                                   Some Like It Hot              A
# 29                                            Ben-Hur
# 30                                     Apocalypse Now              C
# 31                                            Amadeus              B
# 32      The Lord of the Rings: The Return of the King              B
# 33                                          Gladiator            B15
# 34                                            Titanic              A
# 35                              From Here to Eternity
# 36                                Saving Private Ryan              B
# 37                                         Unforgiven              B
# 38                            Raiders of the Lost Ark              A
# 39                                              Rocky              A
# 40                           A Streetcar Named Desire             PG
# 41                             The Philadelphia Story
# 42                              To Kill a Mockingbird
# 43                               An American in Paris
# 44                        The Best Years of Our Lives
# 45                                       My Fair Lady              G
# 46                                 A Clockwork Orange              C
# 47                                     Doctor Zhivago          PG-13
# 48                                      The Searchers
# 49                                               Jaws              B
#
#                   Length                                       Genre  \
# 0   1 hr 37 min (97 min)                                Crime, Drama
# 1   1 hr 37 min (97 min)                                       Drama
# 2   1 hr 37 min (97 min)                   History, Biography, Drama
# 3   1 hr 37 min (97 min)                     Biography, Sport, Drama
# 4   1 hr 37 min (97 min)                         Romance, War, Drama
# 5   1 hr 37 min (97 min)                              Mystery, Drama
# 6   1 hr 37 min (97 min)                Romance, History, War, Drama
# 7   1 hr 37 min (97 min)         Fantasy, Musical, Adventure, Family
# 8   1 hr 37 min (97 min)                                       Drama
# 9   1 hr 37 min (97 min)   History, Adventure, Biography, War, Drama
# 10  1 hr 37 min (97 min)                  Mystery, Thriller, Romance
# 11  1 hr 37 min (97 min)                   Horror, Mystery, Thriller
# 12  1 hr 37 min (97 min)                                Crime, Drama
# 13  1 hr 37 min (97 min)                      Thriller, Crime, Drama
# 14  1 hr 37 min (97 min)                            Film-Noir, Drama
# 15  1 hr 37 min (97 min)                              Romance, Drama
# 16  1 hr 37 min (97 min)  Romance, Biography, Drama, Musical, Family
# 17  1 hr 37 min (97 min)                                       Drama
# 18  1 hr 37 min (97 min)              Romance, Crime, Drama, Musical
# 19  1 hr 37 min (97 min)          Fantasy, Sci-Fi, Adventure, Action
# 20  1 hr 37 min (97 min)                           Sci-Fi, Adventure
# 21  1 hr 37 min (97 min)                              Sci-Fi, Family
# 22  1 hr 37 min (97 min)                      Thriller, Crime, Drama
# 23  1 hr 37 min (97 min)                    Mystery, Thriller, Drama
# 24  1 hr 37 min (97 min)                       War, Adventure, Drama
# 25  1 hr 37 min (97 min)                    Comedy, Romance, Musical
# 26  1 hr 37 min (97 min)                      Fantasy, Drama, Family
# 27  1 hr 37 min (97 min)                                      Comedy
# 28  1 hr 37 min (97 min)                      Comedy, Music, Romance
# 29  1 hr 37 min (97 min)                   History, Adventure, Drama
# 30  1 hr 37 min (97 min)                                  War, Drama
# 31  1 hr 37 min (97 min)            History, Biography, Music, Drama
# 32  1 hr 37 min (97 min)                   Fantasy, Adventure, Drama
# 33  1 hr 37 min (97 min)                    Drama, Adventure, Action
# 34  1 hr 37 min (97 min)                              Romance, Drama
# 35  1 hr 37 min (97 min)                         Romance, War, Drama
# 36  1 hr 37 min (97 min)                                  War, Drama
# 37  1 hr 37 min (97 min)                              Western, Drama
# 38  1 hr 37 min (97 min)                           Adventure, Action
# 39  1 hr 37 min (97 min)                                Sport, Drama
# 40  1 hr 37 min (97 min)                                       Drama
# 41  1 hr 37 min (97 min)                             Comedy, Romance
# 42  1 hr 37 min (97 min)                                Crime, Drama
# 43  1 hr 37 min (97 min)                     Romance, Drama, Musical
# 44  1 hr 37 min (97 min)                         Romance, War, Drama
# 45  1 hr 37 min (97 min)             Romance, Musical, Drama, Family
# 46  1 hr 37 min (97 min)                        Sci-Fi, Crime, Drama
# 47  1 hr 37 min (97 min)                         Romance, War, Drama
# 48  1 hr 37 min (97 min)                   Western, Adventure, Drama
# 49  1 hr 37 min (97 min)                  Thriller, Adventure, Drama
#
#     Imdb_Rating Metascore  No_Ratings Release_Date  ... User_reviews  \
# 0           9.2       100     1451346   1972-10-04  ...         3200
# 1           9.3        80     2113978   1994-09-23  ...         6650
# 2           8.9        93     1096633   1994-02-04  ...         1601
# 3           8.2        89      290559   1980-12-19  ...          536
# 4           8.5       100      479858   1943-03-04  ...         1215
# 5           8.3       100      366096   1941-06-06  ...         1357
# 6           8.2        97      265596   1941-01-22  ...          794
# 7           8.0       100      353850   1940-01-01  ...          653
# 8           8.7        83      837147   1975-11-19  ...          875
# 9           8.3       100      244538   1964-05-14  ...          615
# 10          8.3       100      323279   1958-07-21  ...          766
# 11          8.5        97      542627   1962-03-29  ...         1164
# 12          9.0        90     1009225   1974-12-20  ...          820
# 13          8.2        91      129572   1954-06-22  ...          305
# 14          8.4                181159   1950-09-29  ...          552
# 15          8.8        82     1624348   1994-07-06  ...         1965
# 16          8.0        63      183866   1965-11-18  ...          447
# 17          8.9        96      601175   1957-04-10  ...         1311
# 18          7.6        86       88325   1963-04-25  ...          365
# 19          8.6        90     1128211   1977-12-23  ...         1648
# 20          8.3        82      546550   1968-10-31  ...         1985
# 21          7.9        91      339061   1982-12-09  ...          552
# 22          8.6        85     1143104   1991-02-14  ...         1100
# 23          8.2        92      267411   1974-06-20  ...          502
# 24          8.2        87      187096   1963-02-28  ...          304
# 25          8.3        99      198874   1952-10-15  ...          614
# 26          8.6        89      360086   1947-04-16  ...          838
# 27          8.4        97      417502   1965-08-05  ...          893
# 28          8.2        97      222533   1959-10-08  ...          391
# 29          8.1        90      202553   1961-11-16  ...          407
# 30          8.5        94      552680   1979-08-15  ...         1070
# 31          8.3        88      339411   1985-04-04  ...          593
# 32          8.9        94     1504425   2003-12-17  ...         3467
# 33          8.5        67     1220592   2000-05-05  ...         2497
# 34          7.8        75      962558   1998-01-01  ...         2688
# 35          7.7        85       39659   1953-08-28  ...          165
# 36          8.6        91     1119727   1998-09-04  ...         2434
# 37          8.2        85      343849   1992-08-07  ...          547
# 38          8.5        85      817936   1981-06-12  ...          844
# 39          8.1        70      475473   1977-05-05  ...          630
# 40          8.0        96       92016   1951-12-01  ...          262
# 41          8.0        96       58791   1941-07-10  ...          201
# 42          8.3        88      274206   1963-12-19  ...          536
# 43          7.2        84       27527   1951-11-11  ...          158
# 44          8.1        92       53573   1947-05-29  ...          269
# 45          7.9        95       80073   1965-10-21  ...          288
# 46          8.3        80      693875   1974-01-22  ...         1452
# 47          8.0        69       64777   1965-12-31  ...          286
# 48          8.0        94       73491   1956-05-26  ...          460
# 49          8.0        87      513683   1975-06-20  ...         1121
#
#    Critic_reviews  Popularity  \
# 0             241         126
# 1             217          83
# 2             220         262
# 3             178        1816
# 4             184         610
# 5             261        1087
# 6             182         225
# 7             154         310
# 8             163         516
# 9             188        1388
# 10            172        1712
# 11            223         554
# 12            171         547
# 13            148        3547
# 14            161        3161
# 15            158         156
# 16            128        1017
# 17            209         550
# 18            128        1277
# 19            309         407
# 20            254         629
# 21            242         576
# 22            199         280
# 23            243        1722
# 24             90        3108
# 25            150        2614
# 26            156        1814
# 27            225        1457
# 28            210        1697
# 29            127        2448
# 30            290         395
# 31            145        1106
# 32            345         387
# 33            247         163
# 34            323         120
# 35            115        4964
# 36            245         358
# 37            114        1556
# 38            244         399
# 39            171         563
# 40             78        3359
# 41            123         201
# 42            142        1889
# 43             97         158
# 44            119         269
# 45             88        2212
# 46            247         402
# 47             93        3004
# 48            117        2724
# 49            278         232
#
#                                                  Cast  \
# 0   {'Marlon Brando ': 'Don Vito Corleone', 'James...
# 1   {'Tim Robbins ': 'Andy Dufresne', 'Bob Gunton ...
# 2   {'Liam Neeson ': 'Oskar Schindler', 'Ralph Fie...
# 3   {'Robert De Niro ': 'Jake La Motta', 'Joe Pesc...
# 4   {'Humphrey Bogart ': 'Rick Blaine', 'Paul Henr...
# 5   {'Joseph Cotten ': 'Jedediah Leland Screening ...
# 6   {'Thomas Mitchell ': 'Gerald O'Hara', 'Vivien ...
# 7   {'Judy Garland ': 'Dorothy', 'Ray Bolger ': ''...
# 8   {'Jack Nicholson ': 'R.P. McMurphy', 'Will Sam...
# 9   {'Peter O'Toole ': 'T.E. Lawrence', 'Anthony Q...
# 10  {'James Stewart ': 'John 'Scottie' Ferguson', ...
# 11  {'Anthony Perkins ': 'Norman Bates', 'John Gav...
# 12  {'Al Pacino ': 'Michael', 'Diane Keaton ': 'Ka...
# 13  {'Marlon Brando ': 'Terry Malloy', 'Lee J. Cob...
# 14  {'William Holden ': 'Joe Gillis', 'Erich von S...
# 15  {'Tom Hanks ': 'Forrest Gump', 'Sally Field ':...
# 16  {'Julie Andrews ': 'Maria', 'Eleanor Parker ':...
# 17  {'Martin Balsam ': 'Juror 1', 'Lee J. Cobb ': ...
# 18  {'Natalie Wood ': 'Maria', 'Russ Tamblyn ': 'R...
# 19  {'Mark Hamill ': 'Luke Skywalker', 'Carrie Fis...
# 20  {'Keir Dullea ': 'Dr. Dave Bowman', 'William S...
# 21  {'Dee Wallace ': 'Mary', 'Peter Coyote ': 'Key...
# 22  {'Jodie Foster ': 'Clarice Starling', 'Kasi Le...
# 23  {'Jack Nicholson ': 'J.J. Gittes', 'John Husto...
# 24  {'William Holden ': 'Shears', 'Jack Hawkins ':...
# 25  {'Gene Kelly ': 'Don Lockwood', 'Debbie Reynol...
# 26  {'James Stewart ': 'George Bailey', 'Lionel Ba...
# 27  {'Peter Sellers ': 'Group Capt. Lionel Mandrak...
# 28  {'Marilyn Monroe ': 'Sugar Kane Kowalczyk', 'J...
# 29  {'Charlton Heston ': 'Judah Ben-Hur', 'Haya Ha...
# 30  {'Marlon Brando ': 'Colonel Walter E. Kurtz', ...
# 31  {'F. Murray Abraham ': 'Antonio Salieri', 'Eli...
# 32  {'Noel Appleby ': 'Everard Proudfoot', 'Sean A...
# 33  {'Russell Crowe ': 'Maximus', 'Connie Nielsen ...
# 34  {'Leonardo DiCaprio ': 'Jack Dawson', 'Billy Z...
# 35  {'Burt Lancaster ': 'Sgt. Milton Warden', 'Deb...
# 36  {'Tom Hanks ': 'Captain Miller', 'Edward Burns...
# 37  {'Clint Eastwood ': 'Bill Munny', 'Morgan Free...
# 38  {'Harrison Ford ': 'Indy', 'Paul Freeman ': 'B...
# 39  {'Sylvester Stallone ': 'Rocky', 'Burt Young '...
# 40  {'Vivien Leigh ': 'Blanche DuBois', 'Kim Hunte...
# 41  {'Cary Grant ': 'C. K. Dexter Haven', 'James S...
# 42  {'Gregory Peck ': 'Atticus Finch', 'Frank Over...
# 43  {'Gene Kelly ': 'Jerry Mulligan', 'Oscar Levan...
# 44  {'Myrna Loy ': 'Milly Stephenson', 'Dana Andre...
# 45  {'Audrey Hepburn ': 'Eliza Doolittle', 'Stanle...
# 46  {'Malcolm McDowell ': 'Alex', 'Michael Bates '...
# 47  {'Omar Sharif ': 'Yuri', 'Geraldine Chaplin ':...
# 48  {'John Wayne ': 'Ethan Edwards', 'Vera Miles '...
# 49  {'Roy Scheider ': 'Brody', 'Richard Dreyfuss '...
#
#                                              Taglines  \
# 0                  An offer you can't refuse.
# 1   Fear can hold you prisoner. Hope can set you f...
# 2   Whoever saves one life, saves the world entire...
# 3
# 4   As big and timely a picture as ever you've see...
# 5       Everybody's talking about it!
# 6   Winner of Ten Academy Awards [reissue]        ...
# 7   Amazing Sights To See ! The Tornado . . . Munc...
# 8     If he's crazy, what does that make you?
# 9   An Epic Masterpiece As You've Never Seen It Be...
# 10  Alfred Hitchcock engulfs you in a whirlpool of...
# 11    The Essential Alfred Hitchcock.
# 12  All the power on earth can't change destiny.  ...
# 13  The Man Lived by the Jungle Law of the Docks! ...
# 14                  A Hollywood Story
# 15  The world will never be the same once you've s...
# 16  The Happiest Sound In All The World!          ...
# 17  Life Is In Their Hands -- Death Is On Their Mi...
# 18  Unlike other classics, West Side Story grows y...
# 19  The force will be with you (re-release)       ...
# 20  50 Years Ago One Movie Changed All Movies Fore...
# 21  He is afraid. He is alone. He is three million...
# 22        May The Silence Be Broken!!
# 23  The most highly acclaimed film of 1974!       ...
# 24  It spans a whole new world of entertainment!  ...
# 25           MGM's Musical Treasure !
# 26  Wonderful news...about wonderful people!...in ...
# 27      The hot-line suspense comedy.
# 28  Marilyn Monroe and her bosom companions       ...
# 29  The World's Most Honored Motion Picture       ...
# 30            The Horror. . . The Horror. . .
# 31  The man... The music... The madness... The mur...
# 32  There can be no triumph without loss. No victo...
# 33  What We Do In Life Echoes In Eternity.        ...
# 34  Nothing On Earth Could Come Between Them.     ...
# 35  Pouring out of impassioned pages...brawling th...
# 36              The mission is a man.
# 37      It's a hell of a thing, killing a man
# 38  Indiana Jones - the new hero from the creators...
# 39  His whole life was a million-to-one shot.     ...
# 40  THE PULITZER PRIZE PLAY of New Orleans' Latin ...
# 41  Broadway's howling year-run comedy hit of the ...
# 42  Academy Award winner! Best Actor Gregory Peck ...
# 43  What a joy! It's M-G-M's Technicolor musical! ...
# 44  The Most Honored Picture of All Time (1954 wid...
# 45  The loverliest motion picture of them all!    ...
# 46  Being the adventures of a young man whose prin...
# 47  In a world of guns and ice there is the great ...
# 48  The Biggest, Roughest, Toughest ...and Most Be...
# 49  Do you like fish?  Well, he likes you too...  ...
#
#                              Country        Budget Cumulative_Worldwide_Gross  \
# 0                                USA    $6,000,000               $245,066,411
# 1                                USA   $25,000,000                $58,500,000
# 2                                USA   $22,000,000               $221,000,000
# 3                           See more   $18,000,000
# 4                                USA      $950,000               $14,952,620,
# 5                                USA      $839,727
# 6                                USA    $3,977,000               $400,176,459
# 7                                USA    $2,800,000
# 8                            English    $4,400,000
# 9                                 UK   $15,000,000                $77,324,144
# 10                           English    $2,479,000               $25,000,000,
# 11                           English      $806,947               $50,000,000,
# 12                               USA   $13,000,000
# 13                               USA      $910,000
# 14                           English    $1,752,000                 $5,303,175
# 15                               USA   $55,000,000               $677,945,399
# 16                               USA    $8,200,000               $286,214,286
# 17                               USA      $350,000
# 18                 English / Spanish    $6,000,000
# 19                               USA   $11,000,000              $775,398,007,
# 20                          UK / USA   $12,000,000               $190,700,000
# 21                               USA   $10,500,000              $792,910,554,
# 22                               USA   $19,000,000               $272,742,922
# 23     English / Cantonese / Spanish    $6,000,000               $30,000,000,
# 24         English / Japanese / Thai    $3,000,000
# 25                           English    $2,540,800                $13,979,088
# 26                  English / French    $3,180,000
# 27                 English / Russian    $1,800,000
# 28                           English    $2,883,848
# 29                           English   $15,900,000               $196,200,000
# 30                               USA   $31,500,000
# 31     USA / France / Czechoslovakia   $18,000,000
# 32                 New Zealand / USA   $94,000,000            $1,119,929,521,
# 33        USA / UK / Malta / Morocco  $103,000,000              $457,640,427,
# 34                               USA  $200,000,000            $2,186,772,302,
# 35                           English    $1,650,000
# 36                               USA   $70,000,000              $481,840,909,
# 37                               USA   $14,400,000               $159,157,447
# 38                               USA   $18,000,000               $389,925,971
# 39                               USA      $960,000               $225,000,000
# 40                 English / Spanish    $1,800,000
# 41                  English / French
# 42                               USA    $2,000,000
# 43         English / French / German    $2,723,903
# 44                           English    $2,100,000                $44,309,982
# 45                               USA   $17,000,000
# 46                           English    $2,200,000
# 47  USA / Italy / UK / Liechtenstein   $11,000,000
# 48        English / Navajo / Spanish    $3,750,000
# 49                               USA    $8,000,000               $470,653,000
#
#                                                Trivia  \
# 0
# 1
# 2   This film and E.T., El extraterrestre (1982) a...
# 3   Cinematographer Michael Chapman drew inspirati...
# 4
# 5
# 6
# 7   The scene in which the Wicked Witch tries to t...
# 8   (At around six minutes and sixteen seconds) Wh...
# 9   After six months filming in the desert, Peter ...
# 10  In 2012, this movie replaced El ciudadano Kane...
# 11  Norman's parlor features many stuffed birds, s...
# 12
# 13  The film was shot by Elia Kazan at the aspect ...
# 14  For the first industry screening, Paramount ex...
# 15  In Vietnam, Forrest was assigned to 4th Platoo...
# 16
# 17  There are no female characters in the film, as...
# 18  The reason Natalie Wood had Richard Beymer on ...
# 19
# 20  Both Tom Hanks and Gale Anne Hurd named this a...
# 21  Included among the "1001 Movies You Must See B...
# 22
# 23
# 24  Assistant Director John Kerrison was killed in...
# 25  This was the seventh time the song "Singin' in...
# 26  The pictures in the Granville house are all fr...
# 27  The illuminated symbols on the War Room map di...
# 28  The sequences set in Florida were shot on loca...
# 29  William Wyler decided to take Charlton Heston ...
# 30  Burt Reynolds was offered the role of Willard....
# 31
# 32
# 33  In reality, Emperor Marcus Aurelius (Sir Richa...
# 34  Included among the "1001 Movies You Must See B...
# 35
# 36  After completing this movie, Steven Spielberg ...
# 37  Most of the rain in the film was specially cre...
# 38
# 39  For the championship fight, the filmmakers had...
# 40  Due to the highly contentious subject matter, ...
# 41  "Theater Guild on the Air" broadcast a 60-minu...
# 42      Grossed over $13 million in its U.S. release.
# 43  During filming, Nina Foch came down with chick...
# 44  When Homer is lighting everyone's cigarettes, ...
# 45
# 46
# 47     This movie was not shown in Russia until 1994.
# 48
# 49  Director Steven Spielberg observed at the firs...
#
#                                                  Goof
# 0   While Michael is talking to Apollonia's father...
# 1   Towards the beginning of the film, during a be...
# 2   When Oskar is in bed with his wife and talking...
# 3   When Jake and Joey are sitting at the kitchen ...
# 4   The German Wehrmacht-Heer (army) personnel sho...
# 5   At the party scene where Kane dances with the ...
# 6   After Ashley Wilkes is carried into his room f...
# 7   When the Witch sees the ruby slippers under th...
# 8   After the Christmas party, and Randall is wait...
# 9   General Sir Edmund Allenby (promoted to Field ...
# 10  The parked cars opposite the alley behind the ...
# 11  When Norman discovers Marion's body in the sho...
# 12  When Vito Corleone and Don Tommasino pay a vis...
# 13  The position of Johnny's scarf changes between...
# 14  As the policemen run towards the pool, you can...
# 15  When Forrest and Lieutenant Dan are celebratin...
# 16  The first time Maria goes to see the Reverend ...
# 17  During the jury deliberation, Juror #3 and Jur...
# 18  In the opening number, which was shot on locat...
# 19  Footage of R2-D2 turning his head skeptically ...
# 20  When the moon monolith, which has been buried ...
# 21  When E.T. runs through the swing set he sets e...
# 22  When Sgt. Pembry is preparing to handcuff Dr. ...
# 23  In the land records office, the surly young cl...
# 24  It wouldn't have been necessary for Joyce, the...
# 25  After the "Beautiful Girl" number, Mr. Simpson...
# 26  When George and Mary are throwing rocks at the...
# 27  After Major Kong lists the contents of the eme...
# 28  When Joe and Jerry arrive at Poliakoff's build...
# 29  After Judah denounces Rome and Esther declares...
# 30  Shadow of dolly and crew just before the scene...
# 31  The Emperor Francis recalls an incident betwee...
# 32  Near the beginning, after a toast, Aragorn til...
# 33  Proximo tells the trader he'll give him "2000 ...
# 34  When Rose breaks the glass to get the fire axe...
# 35  A bugler who is as good as Prewitt would never...
# 36  Several flamethrower troops are depicted as be...
# 37  At the first time in the saloon, Munny pushes ...
# 38  Indiana Jones never loses his hat, yet he swim...
# 39  The number "2" disappears off Rocky's apartmen...
# 40  When Stanley comes back from taking Stella to ...
# 41  At around 1 hour 39 mins into the movie, Cary ...
# 42  While lying unconscious in his bed after Boo R...
# 43  In the "By Strauss" waltz, Jerry is dancing wi...
# 44  After Fred Derry dresses after staying the nig...
# 45  In the pub scene ("I'm getting married in the ...
# 46  Position of the prison governor's hands when h...
# 47  The book on the table in front of Tonya change...
# 48  Ethan and Mose are on horseback and pass Marti...
# 49  During the first chum-line scene, Quint's fish...
#
# [50 rows x 22 columns]

# %% [markdown]
# Finally, all the information in `movies_df` is saved as a CSV file calling for the respective method of the dataframe.

# %%
movies_df.to_csv('Data_from_Web_Scraping.csv', index = False)
