# %% [markdown]
# # Web Scraper

# %%
import requests
from bs4 import BeautifulSoup
import time
import re


class IronhackSpider:
    
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    

    def scrape_url(self, url):
        try:
            response = requests.get(url)
            result = self.content_parser(response.content)
            self.output_results(result)
        except exception as excep:
            print(type(excep), excep)
            print('ERROR!')
    
   
    def output_results(self, r):
        print(r)
    

    def kickstart(self, sleep_interval = 0):
        if self.sleep_interval > 0:  
            for i in range(1, self.pages_to_scrape+1):
                self.scrape_url(self.url_pattern % i)
                time.sleep(self.sleep_interval)


URL_PATTERN = 'http://quotes.toscrape.com/page/%s/' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 1 # how many webpages to scrapge

def quotes_parser(content):
    return content

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
# my_spider.kickstart()

# %%
URL_PATTERN = 'http://www.starcitygames.com/catalog/magic_the_gathering/'
PAGES_TO_SCRAPE = 1

def quotes_parser(content):
    content = BeautifulSoup(content, 'html')
    nueva_sopa = content.find_all('ul', {'class':'cardset_lists'})
    text = [i.get_text()for i in nueva_sopa]
    print(text)
    return text
quotes_parser = quotes_parser
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser) 
my_spider.kickstart()

# %%
#catalog = requests.get('http://www.starcitygames.com/catalog/magic_the_gathering/').content
#catalog_web = BeautifulSoup(catalog, 'html')


links_to_categories = catalog_web.select('ul.cardset_lists a[href^= "http://www.starcitygames.com/catalog/category/"]')
links = [link['href'] for link in links_to_categories]
print(links)
# Out:
# ['http://www.starcitygames.com/catalog/category/10th Edition', 'http://www.starcitygames.com/catalog/category/3rd EditionRevised', 'http://www.starcitygames.com/catalog/category/4th Edition', 'http://www.starcitygames.com/catalog/category/5th Edition', 'http://www.starcitygames.com/catalog/category/6th Edition', 'http://www.starcitygames.com/catalog/category/7th Edition', 'http://www.starcitygames.com/catalog/category/8th Edition', 'http://www.starcitygames.com/catalog/category/9th Edition', 'http://www.starcitygames.com/catalog/category/Aether Revolt', 'http://www.starcitygames.com/catalog/category/Alara Reborn', 'http://www.starcitygames.com/catalog/category/Alliances', 'http://www.starcitygames.com/catalog/category/Alpha', 'http://www.starcitygames.com/catalog/category/Alternate 4th Edition', 'http://www.starcitygames.com/catalog/category/Amonkhet', 'http://www.starcitygames.com/catalog/category/Anthologies', 'http://www.starcitygames.com/catalog/category/Antiquities', 'http://www.starcitygames.com/catalog/category/Apocalypse', 'http://www.starcitygames.com/catalog/category/Arabian Nights', 'http://www.starcitygames.com/catalog/category/Archenemy 2010 Edition', 'http://www.starcitygames.com/catalog/category/Archenemy Schemes 2010 Edition', 'http://www.starcitygames.com/catalog/category/Archenemy Schemes Nicol Bolas', 'http://www.starcitygames.com/catalog/category/Archenemy Nicol Bolas', 'http://www.starcitygames.com/catalog/category/Avacyn Restored', 'http://www.starcitygames.com/catalog/category/Battle for Zendikar', 'http://www.starcitygames.com/catalog/category/Battle Royale', 'http://www.starcitygames.com/catalog/category/Battlebond', 'http://www.starcitygames.com/catalog/category/Beatdown', 'http://www.starcitygames.com/catalog/category/Beta', 'http://www.starcitygames.com/catalog/category/Betrayers of Kamigawa', 'http://www.starcitygames.com/catalog/category/Born of the Gods', 'http://www.starcitygames.com/catalog/category/Champions of Kamigawa', 'http://www.starcitygames.com/catalog/category/Chronicles', 'http://www.starcitygames.com/catalog/category/Coldsnap', 'http://www.starcitygames.com/catalog/category/Coldsnap Theme Deck Reprints', 'http://www.starcitygames.com/catalog/category/Collectors Edition', 'http://www.starcitygames.com/catalog/category/Commander 2011 Edition', 'http://www.starcitygames.com/catalog/category/Commander 2013 Edition', 'http://www.starcitygames.com/catalog/category/Commander 2014 Edition', 'http://www.starcitygames.com/catalog/category/Commander 2015 Edition', 'http://www.starcitygames.com/catalog/category/Commander 2016 Edition', 'http://www.starcitygames.com/catalog/category/Commander 2017 Edition', 'http://www.starcitygames.com/catalog/category/Commander 2018 Edition', 'http://www.starcitygames.com/catalog/category/Commander 2019 Edition', 'http://www.starcitygames.com/catalog/category/Commander Anthology', 'http://www.starcitygames.com/catalog/category/Commander Anthology Volume II', 'http://www.starcitygames.com/catalog/category/Conflux', 'http://www.starcitygames.com/catalog/category/Conspiracy 2014 Edition', 'http://www.starcitygames.com/catalog/category/Conspiracy Take the Crown', 'http://www.starcitygames.com/catalog/category/Core Set 2019', 'http://www.starcitygames.com/catalog/category/Core Set 2020', 'http://www.starcitygames.com/catalog/category/Dark Ascension', 'http://www.starcitygames.com/catalog/category/Darksteel', 'http://www.starcitygames.com/catalog/category/Deckmasters', 'http://www.starcitygames.com/catalog/category/Dissension', 'http://www.starcitygames.com/catalog/category/Dominaria', 'http://www.starcitygames.com/catalog/category/Dragons Maze', 'http://www.starcitygames.com/catalog/category/Dragons of Tarkir', 'http://www.starcitygames.com/catalog/category/Duel Decks Ajani vs Nicol Bolas', 'http://www.starcitygames.com/catalog/category/Duel Decks Anthology', 'http://www.starcitygames.com/catalog/category/Duel Decks Blessed vs Cursed', 'http://www.starcitygames.com/ ...

# %%
catalog = requests.get('http://www.starcitygames.com/catalog/category/Oath%20of%20the%20Gatewatch').content
catalog_web = BeautifulSoup(catalog, 'html')
#print(catalog_web.prettify())

links_to_categories = catalog_web.select('tr.deckdbbody_row, deckdbbody2_row:nth-child(1)')
#links_to_categories = catalog_web.find_all('td', {'class': re.compile('search_results_9$')})
print(links_to_categories)
#links_to_categories = [link.text for link in links_to_categories]

#print(tmp3)
links = [re.sub(r'[\n\n\n\n\n\n\n\n]', '    ', link.text).strip(' , \xa0').split('    ') for link in links_to_categories]
#print(links)
# Out:
# [<tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201636" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/AbstruseInterference.jpg' alt='Abstruse Interference' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Abstruse Interference">
# Abstruse Interference</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-2 ms-cost"></i><i class="ms ms-u ms-cost"></i></td><td class="deckdbbody search_results_4">Instant</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">95</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201636" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201636">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201636" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201675" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/AkoumFlameseeker.jpg' alt='Akoum Flameseeker' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Akoum Flameseeker">
# Akoum Flameseeker</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-2 ms-cost"></i><i class="ms ms-r ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Human Shaman Ally</td><td class="deckdbbody search_results_5">3/2</td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">78</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201675" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201675">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201675" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201643" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/AncientCrab.jpg' alt='Ancient Crab' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Ancient Crab">
# Ancient Crab</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-1 ms-cost"></i><i class="ms ms-u ms-cost"></i><i class="ms ms-u ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Crab</td><td class="deckdbbody search_results_5">1/5</td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">97</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201643" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201643">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201643" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201588" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/BalothNull.jpg' alt='Baloth Null' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Baloth Null">
# Baloth Null</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-4 ms-cost"></i><i class="ms ms-b ms-cost"></i><i class="ms ms-g ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Zombie Beast</td><td class="deckdbbody search_results_5">4/5</td>
# <td class="deckdbbody search_results_6">U</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">84</td><td class="deckdbbody search_results_9">$0.25</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201588" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201588">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201588" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201602" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/BearerOfSilence.jpg' alt='Bearer of Silence' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Bearer of Silence">
# Bearer of Silence</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-1 ms-cost"></i><i class="ms ms-b ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi</td><td class="deckdbbody search_results_5">2/1</td>
# <td class="deckdbbody search_results_6">R</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">44</td><td class="deckdbbody search_results_9">$0.49</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201602" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201602">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201602" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201637" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/BlindingDrone.jpg' alt='Blinding Drone' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Blinding Drone">
# Blinding Drone</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-1 ms-cost"></i><i class="ms ms-u ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi Drone</td><td class="deckdbbody search_results_5">1/3</td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">99</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201637" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201637">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201637" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201584" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/BoneSaw.jpg' alt='Bone Saw' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Bone Saw">
# Bone Saw</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-0 ms-cost"></i></td><td class="deckdbbody search_results_4">Artifact - Equipment</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">54</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201584" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201584">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201584" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201676" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/BruteStrength.jpg' alt='Brute Strength' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Brute Strength">
# Brute Strength</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-1 ms-cost"></i><i class="ms ms-r ms-cost"></i></td><td class="deckdbbody search_results_4">Instant</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">89</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201676" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201676">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201676" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201688" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/CanopyGorger.jpg' alt='Canopy Gorger' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Canopy Gorger">
# Canopy Gorger</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-4 ms-cost"></i><i class="ms ms-g ms-cost"></i><i class="ms ms-g ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Wurm</td><td class="deckdbbody search_results_5">6/5</td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">89</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201688" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201688">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201688" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201424/1202239/1202240" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/ChandraFlamecaller.jpg' alt='Chandra, Flamecaller' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Chandra, Flamecaller">
# Chandra, Flamecaller</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-4 ms-cost"></i><i class="ms ms-r ms-cost"></i><i class="ms ms-r ms-cost"></i></td><td class="deckdbbody search_results_4">Legendary Planeswalker - Chandra</td><td class="deckdbbody search_results_5">4</td>
# <td class="deckdbbody search_results_6">M</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td>
# <td class="deckdbbody search_results_8">Out of Stock</td>
# <td class="deckdbbody search_results_9">$2.99</td>
# <td class="deckdbbody search_results_10">
# <div>
# <button class="btn btn-sm btn-success restock_alert" data-product="1201424" id="restock_1201424">Restock Alert</button>
# </div></td></tr>, <tr class="deckdbbody_row">
# <td class="deckdbbody_notop search_results_1"> </td>
# <td class="deckdbbody_notop search_results_2"> </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-4 ms-cost"></i><i class="ms ms-r ms-cost"></i><i class="ms ms-r ms-cost"></i></td><td class="deckdbbody search_results_4">Legendary Planeswalker - Chandra</td><td class="deckdbbody search_results_5">4</td>
# <td class="deckdbbody search_results_6">M</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">PL</a></td><td class="deckdbbody search_results_8">28</td><td class="deckdbbody search_results_9">$2.45</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1202239" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1202239">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1202239" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row">
# <td class="deckdbbody_notop search_results_1"> </td>
# <td class="deckdbbody_notop search_results_2"> </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-4 ms-cost"></i><i class="ms ms-r ms-cost"></i><i class="ms ms-r ms-cost"></i></td><td class="deckdbbody search_results_4">Legendary Planeswalker - Chandra</td><td class="deckdbbody search_results_5">4</td>
# <td class="deckdbbody search_results_6">M</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">HP</a></td><td class="deckdbbody search_results_8">7</td><td class="deckdbbody search_results_9"><span style="text-decoration:line-through;">$1.49</span><br/><span style="color:red; font-weight:bold;">$1.42</span></td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1202240" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1202240">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1202240" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201527" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/CinderBarrens.jpg' alt='Cinder Barrens' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Cinder Barrens">
# Cinder Barrens</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"></td><td class="deckdbbody search_results_4">Land</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">U</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">167</td><td class="deckdbbody search_results_9">$0.25</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201527" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201527">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201527" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201587" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/CliffhavenVampire.jpg' alt='Cliffhaven Vampire' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Cliffhaven Vampire">
# Cliffhaven Vampire</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-2 ms-cost"></i><i class="ms ms-w ms-cost"></i><i class="ms ms-b ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Vampire Warrior Ally</td><td class="deckdbbody search_results_5">2/4</td>
# <td class="deckdbbody search_results_6">U</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">94</td><td class="deckdbbody search_results_9">$0.29</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201587" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201587">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201587" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201670" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/ConsumingSinkhole.jpg' alt='Consuming Sinkhole' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Consuming Sinkhole">
# Consuming Sinkhole</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-3 ms-cost"></i><i class="ms ms-r ms-cost"></i></td><td class="deckdbbody search_results_4">Instant</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">76</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201670" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201670">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201670" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201662" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/CorpseChurn.jpg' alt='Corpse Churn' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Corpse Churn">
# Corpse Churn</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-1 ms-cost"></i><i class="ms ms-b ms-cost"></i></td><td class="deckdbbody search_results_4">Instant</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">89</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201662" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201662">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201662" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201425" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/CrumblingVestige.jpg' alt='Crumbling Vestige' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Crumbling Vestige">
# Crumbling Vestige</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"></td><td class="deckdbbody search_results_4">Land</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">205</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201425" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201425">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201425" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201638" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/CultivatorDrone.jpg' alt='Cultivator Drone' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Cultivator Drone">
# Cultivator Drone</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-2 ms-cost"></i><i class="ms ms-u ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi Drone</td><td class="deckdbbody search_results_5">2/3</td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">62</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201638" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201638">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201638" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201621" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/DazzlingReflection.jpg' alt='Dazzling Reflection' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Dazzling Reflection">
# Dazzling Reflection</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-1 ms-cost"></i><i class="ms ms-w ms-cost"></i></td><td class="deckdbbody search_results_4">Instant</td><td class="deckdbbody search_results_5"></td>
# <td class="deckdbbody search_results_6">C</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">73</td><td class="deckdbbody search_results_9">$0.15</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201621" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201621">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201621" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201486" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/DeepfathomSkulker.jpg' alt='Deepfathom Skulker' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Deepfathom Skulker">
# Deepfathom Skulker</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-5 ms-cost"></i><i class="ms ms-u ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi</td><td class="deckdbbody search_results_5">4/4</td>
# <td class="deckdbbody search_results_6">R</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">30</td><td class="deckdbbody search_results_9">$0.49</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201486" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201486">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201486" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201614" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/DimensionalInfiltrator.jpg' alt='Dimensional Infiltrator' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Dimensional Infiltrator">
# Dimensional Infiltrator</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-1 ms-cost"></i><i class="ms ms-u ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi</td><td class="deckdbbody search_results_5">2/1</td>
# <td class="deckdbbody search_results_6">R</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">25</td><td class="deckdbbody search_results_9">$0.49</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201614" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201614">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201614" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201485" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/DreadDefiler.jpg' alt='Dread Defiler' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Dread Defiler">
# Dread Defiler</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-6 ms-cost"></i><i class="ms ms-b ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi</td><td class="deckdbbody search_results_5">6/8</td>
# <td class="deckdbbody search_results_6">R</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">35</td><td class="deckdbbody search_results_9">$0.49</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201485" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201485">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201485" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201536/1202283" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/EldraziDisplacer.jpg' alt='Eldrazi Displacer' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Eldrazi Displacer">
# Eldrazi Displacer</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-2 ms-cost"></i><i class="ms ms-w ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi</td><td class="deckdbbody search_results_5">3/3</td>
# <td class="deckdbbody search_results_6">R</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td>
# <td class="deckdbbody search_results_8">Out of Stock</td>
# <td class="deckdbbody search_results_9">$2.49</td>
# <td class="deckdbbody search_results_10">
# <div>
# <button class="btn btn-sm btn-success restock_alert" data-product="1201536" id="restock_1201536">Restock Alert</button>
# </div></td></tr>, <tr class="deckdbbody_row">
# <td class="deckdbbody_notop search_results_1"> </td>
# <td class="deckdbbody_notop search_results_2"> </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-2 ms-cost"></i><i class="ms ms-w ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi</td><td class="deckdbbody search_results_5">3/3</td>
# <td class="deckdbbody search_results_6">R</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">PL</a></td><td class="deckdbbody search_results_8">38</td><td class="deckdbbody search_results_9">$2.05</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1202283" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1202283">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1202283" type="submit" value=" Buy "/>
# </div>
# </td></tr>, <tr class="deckdbbody_row"><td class="deckdbbody search_results_1"><b><a class="card_popup" href="http://www.starcitygames.com/catalog/magic_the_gathering/product/1201509" rel="&lt;div style='text-align: center;'&gt;&lt;img src='http://static.starcitygames.com/sales/cardscans/MTG/OGW/en/nonfoil/EldraziObligator.jpg' alt='Eldrazi Obligator' border='0' align='right' style='max-width:235px'/&gt;&lt;/div&gt;" tooltip="Eldrazi Obligator">
# Eldrazi Obligator</a></b></td><td class="deckdbbody search_results_2">
# <a href="http://www.starcitygames.com/catalog/category/Oath+of+the+Gatewatch">Oath of the Gatewatch</a>
# </td><td class="deckdbbody search_results_3" nowrap="nowrap" style="font-size:14px;"><i class="ms ms-2 ms-cost"></i><i class="ms ms-r ms-cost"></i></td><td class="deckdbbody search_results_4">Creature - Eldrazi</td><td class="deckdbbody search_results_5">3/1</td>
# <td class="deckdbbody search_results_6">R</td>
# <td class="deckdbbody search_results_7"><a href="http://www.starcitygames.com/content/cardconditions">NM/M</a></td><td class="deckdbbody search_results_8">35</td><td class="deckdbbody search_results_9">$0.49</td><td class="deckdbbody search_results_10">
# <div>
# <input class="cart_qty" id="qty_1201509" maxlength="4" name="qty" size="2" type="text" value="0"/>
# <a class="add_button" href="javascript:;" id="add_button_1201509">
# <i class="fa fa-plus-square"></i>
# </a>
# <input class="btn btn-primary btn-sm search_buy_button" id="buy_1201509" type="submit" value=" Buy "/>
# </div>
# </td></tr>]

# %%
catalog = requests.get('http://www.starcitygames.com/catalog/category/Oath%20of%20the%20Gatewatch').content
catalog_web = BeautifulSoup(catalog, 'html')
#print(catalog_web.prettify())

card_name = catalog_web.find_all('td', {'class': 'deckdbbody search_results_1'})
card_name = [link.text for link in card_name]
#print(card_name)

expansion = catalog_web.find_all('td', {'class': 'deckdbbody search_results_2'})
expansion = [link.text for link in expansion]
#print(expansion)

card_type = catalog_web.find_all('td', {'class': 'deckdbbody search_results_4'})
card_type = [link.text for link in card_type]
#print(card_type)
                                                  
rarity = catalog_web.find_all('td', {'class': 'deckdbbody search_results_6'})
rarity = [link.text for link in rarity]
#print(rarity)

price = catalog_web.select('tr > td:')
#price = [link.text for link in price]
for element in price:
    print(element)
    print('\n')

# %%
import pandas as pd
table = pd.read_html(catalog)
df_table = table[1]

# %%
df_table = df_table.drop(0)

name = df_table.iloc[0,]
df_table = df_table.rename(name, axis = 1)
df_table = df_table.drop(1)
df_table = df_table.drop(['Mana', 'Stock'], axis = 1)

#df_table.columns[7]
df_table = df_table.drop(df_table.columns[7],  axis = 1)
df_table = df_table.reset_index(drop = True)
df_table #.isnull()
# Out:
#                        Name               Category  \
# 0     Abstruse Interference  Oath of the Gatewatch
# 1            Affa Protector  Oath of the Gatewatch
# 2         Akoum Flameseeker  Oath of the Gatewatch
# 3     Allied Reinforcements  Oath of the Gatewatch
# 4              Ancient Crab  Oath of the Gatewatch
# 5     Ayli, Eternal Pilgrim  Oath of the Gatewatch
# 6                       NaN                    NaN
# 7               Baloth Null  Oath of the Gatewatch
# 8                Baloth Pup  Oath of the Gatewatch
# 9         Bearer of Silence  Oath of the Gatewatch
# 10            Birthing Hulk  Oath of the Gatewatch
# 11           Blinding Drone  Oath of the Gatewatch
# 12       Bonds of Mortality  Oath of the Gatewatch
# 13                 Bone Saw  Oath of the Gatewatch
# 14            Boulder Salvo  Oath of the Gatewatch
# 15           Brute Strength  Oath of the Gatewatch
# 16       Call the Gatewatch  Oath of the Gatewatch
# 17                      NaN                    NaN
# 18            Canopy Gorger  Oath of the Gatewatch
# 19          Captain's Claws  Oath of the Gatewatch
# 20     Chandra, Flamecaller  Oath of the Gatewatch
# 21                      NaN                    NaN
# 22                      NaN                    NaN
# 23          Chitinous Cloak  Oath of the Gatewatch
# 24           Cinder Barrens  Oath of the Gatewatch
# 25           Cinder Hellion  Oath of the Gatewatch
# 26       Cliffhaven Vampire  Oath of the Gatewatch
# 27     Comparative Analysis  Oath of the Gatewatch
# 28       Consuming Sinkhole  Oath of the Gatewatch
# 29     Containment Membrane  Oath of the Gatewatch
# 30             Corpse Churn  Oath of the Gatewatch
# 31     Corrupted Crossroads  Oath of the Gatewatch
# 32        Crumbling Vestige  Oath of the Gatewatch
# 33       Crush of Tentacles  Oath of the Gatewatch
# 34                      NaN                    NaN
# 35         Cultivator Drone  Oath of the Gatewatch
# 36             Cyclone Sire  Oath of the Gatewatch
# 37      Dazzling Reflection  Oath of the Gatewatch
# 38         Deceiver of Form  Oath of the Gatewatch
# 39       Deepfathom Skulker  Oath of the Gatewatch
# 40         Devour in Flames  Oath of the Gatewatch
# 41  Dimensional Infiltrator  Oath of the Gatewatch
# 42           Drana's Chosen  Oath of the Gatewatch
# 43            Dread Defiler  Oath of the Gatewatch
# 44        Eldrazi Aggressor  Oath of the Gatewatch
# 45        Eldrazi Displacer  Oath of the Gatewatch
# 46                      NaN                    NaN
# 47            Eldrazi Mimic  Oath of the Gatewatch
# 48                      NaN                    NaN
# 49        Eldrazi Obligator  Oath of the Gatewatch
#
#                                 Type  P/T Rarity Condition       Price
# 0                            Instant  NaN      C      NM/M       $0.15
# 1      Creature - Human Soldier Ally  1/4      C      NM/M       $0.15
# 2       Creature - Human Shaman Ally  3/2      C      NM/M       $0.15
# 3                            Sorcery  NaN      U      NM/M       $0.25
# 4                    Creature - Crab  1/5      C      NM/M       $0.15
# 5    Legendary Creature - Kor Cleric  2/3      R      NM/M       $0.79
# 6    Legendary Creature - Kor Cleric  2/3      R        PL       $0.65
# 7            Creature - Zombie Beast  4/5      U      NM/M       $0.25
# 8                   Creature - Beast  3/1      U      NM/M       $0.25
# 9                 Creature - Eldrazi  2/1      R      NM/M       $0.49
# 10          Creature - Eldrazi Drone  5/4      U      NM/M       $0.25
# 11          Creature - Eldrazi Drone  1/3      C      NM/M       $0.15
# 12                       Enchantment  NaN      U      NM/M       $0.25
# 13              Artifact - Equipment  NaN      C      NM/M       $0.15
# 14                           Sorcery  NaN      C      NM/M       $0.15
# 15                           Instant  NaN      C      NM/M       $0.15
# 16                           Sorcery  NaN      R      NM/M       $0.99
# 17                           Sorcery  NaN      R        PL       $0.79
# 18                   Creature - Wurm  6/5      C      NM/M       $0.15
# 19              Artifact - Equipment  NaN      R      NM/M       $0.49
# 20  Legendary Planeswalker - Chandra    4      M      NM/M       $2.99
# 21  Legendary Planeswalker - Chandra    4      M        PL       $2.45
# 22  Legendary Planeswalker - Chandra    4      M        HP  $1.49$1.42
# 23              Artifact - Equipment  NaN      U      NM/M       $0.25
# 24                              Land  NaN      U      NM/M       $0.25
# 25                Creature - Hellion  4/4      C      NM/M       $0.15
# 26   Creature - Vampire Warrior Ally  2/4      U      NM/M       $0.29
# 27                           Instant  NaN      C      NM/M       $0.15
# 28                           Instant  NaN      C      NM/M       $0.15
# 29                Enchantment - Aura  NaN      C      NM/M       $0.15
# 30                           Instant  NaN      C      NM/M       $0.15
# 31                              Land  NaN      R      NM/M       $0.49
# 32                              Land  NaN      C      NM/M       $0.15
# 33                           Sorcery  NaN      M      NM/M       $1.49
# 34                           Sorcery  NaN      M        PL       $1.19
# 35          Creature - Eldrazi Drone  2/3      C      NM/M       $0.15
# 36              Creature - Elemental  3/4      U      NM/M       $0.25
# 37                           Instant  NaN      C      NM/M       $0.15
# 38                Creature - Eldrazi  8/8      R      NM/M       $0.49
# 39                Creature - Eldrazi  4/4      R      NM/M       $0.49
# 40                           Sorcery  NaN      U      NM/M       $0.25
# 41                Creature - Eldrazi  2/1      R      NM/M       $0.49
# 42    Creature - Vampire Shaman Ally  2/2      R      NM/M       $0.49
# 43                Creature - Eldrazi  6/8      R      NM/M       $0.49
# 44          Creature - Eldrazi Drone  2/3      C      NM/M       $0.15
# 45                Creature - Eldrazi  3/3      R      NM/M       $2.49
# 46                Creature - Eldrazi  3/3      R        PL       $2.05
# 47                Creature - Eldrazi  2/1      R      NM/M       $0.99
# 48                Creature - Eldrazi  2/1      R        PL       $0.79
# 49                Creature - Eldrazi  3/1      R      NM/M       $0.49

# %%
URL_PATTERN = 'http://www.starcitygames.com/catalog/category/'
PAGES_TO_SCRAPE = links


class IronhackSpider:
    
    def __init__(self, url_pattern, pages_to_scrape=str, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser



    def scrape_url(self, url):
            try:
                response = requests.get(url).content
                result = self.content_parser(response)
                self.output_results(result)
            except exception as excep:
                print(type(excep), excep)
                print('ERROR!')



    def kickstart(self, sleep_interval = 0):
            if self.sleep_interval > 0:  
                for url in range(self.pages_to_scrape):
                    self.scrape_url(url)
                    time.sleep(self.sleep_interval)



    def quotes_parser(content):
