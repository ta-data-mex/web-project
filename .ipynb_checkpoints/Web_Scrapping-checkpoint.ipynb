# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import Image
import re
import pandas as pd

class web_scrapping_proyecto:

    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser

    def scrape_url(self, url):
        response = requests.get(url)
        result = self.content_parser(response.content)
        self.output_results(result)
        return result
    
    def output_results(self, r):
        #print(r)
        return r
    
    def kickstart(self):
        lista_final=[]
        for i in range(1, self.pages_to_scrape+1):
            z= self.scrape_url("https://www.elsotano.com/ebooks-de/literatura-19/?pagSel=" + str(i) + "&cuantos=20&orden=prioridad%2Cfecha_alta+desc&codMateria=19&tipoArticulo=E")
            #print("_______________________________________________________________________________________________________")
            lista_final.append(z)
        return (lista_final)
    
URL_PATTERN = 'https://www.elsotano.com/ebooks-de/literatura-19/?pagSel=1&cuantos=20&orden=prioridad%2Cfecha_alta+desc&codMateria=19&tipoArticulo=E' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 10 # how many webpages to scrapge

def quotes_parser(content):
    return content
    
    #def csv_file(self, r):
        
        

# Instantiate the IronhackSpider class
my_spider = web_scrapping_proyecto(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
# [b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n                    <meta name="robots" content="index,follow">\n                <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n            <link rel="canonical" href="https://www.elsotano.com/ebooks-de/literatura-19/">\n                \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMetho ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...
#  b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8" lang=""><![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9" lang=""><![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="es"><!--<![endif]-->\n<head>\n    <title>Ebooks de Literatura - Librer\xc3\xada El S\xc3\xb3tano.</title>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="ebooks sobre Literatura - 48673">\n    <meta name="keywords" content="Literatura, ">\n    <meta name="revisit" content="15 days">\n    <meta name="revisit-after" content="1 days">\n    \n            <meta name="robots" content="noindex, nofollow">\n        <meta name="googlebot" content="noindex, nofollow">\n        <meta name="facebook-domain-verification" content="3lxzfy4i5gccf0ac2hkc5de3u701zf" />\n    <meta name="google-site-verification" content="R-5PmIg4zixdZNeSYX_MQprhL4SMxM6LGKLURgojNMU" />\n\n        \n\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-ui.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery.ui.dialog.css">\n    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/lightslider.css">\n    <link rel="stylesheet" type="text/css" href="/css/jquery-labelauty.css">\n    <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap3-dialog/1.34.5/css/bootstrap-dialog.min.css">\n    <link rel="stylesheet" type="text/css" href="/css/style.css?v=1">\n    <link rel="stylesheet" type="text/css" href="/css/square/blue.css">\n    <link rel="stylesheet" type="text/css" href="/css/custom.css">\n\n        \t    <link type="image/x-icon" rel="shortcut icon" href="/images/favicon.ico">\n\n    <!-- alternativa http://schema.org/Organization, igual pero hay que quitar priceRange -->\n    <script type="application/ld+json">\n    {\n    "@context" : "http://schema.org",\n    "@type" : "Store",\n    "name" : "Librer\xc3\xada El S\xc3\xb3tano",\n    "url" : "https://www.elsotano.com",\n    "logo": "https://www.elsotano.com/images/logo-white.png",\n    "address": {\n        "@type": "PostalAddress",\n        "addressLocality": "Coyoac\xc3\xa1n",\n        "addressRegion": "M\xc3\xa9xico",\n        "postalCode": "04310 ",\n        "streetAddress": "M. A. de Quevedo No. 209, Col. Romero de Terreros "\n    },\n    "priceRange": "$$",\n    "image": "https://www.elsotano.com/images/logo.png",\n    "telephone": "800 276 8266 ",\n    "email": "aballesteros@elsotano.com",\n    "sameAs" : [\n            "https://www.facebook.com/LibreriasElSotano",            "https://twitter.com/elsotanolibros",            "https://instagram.com/libreriaselsotano/",            "https://www.youtube.com/user/ElSotanoLibreria",            "https://www.tiktok.com/@libreriaselsotano"    \n    ]\n    }\n    </script>\n    <script type="application/ld+json">\n    {\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.elsotano.com",\n    "potentialAction": {\n        "@type": "SearchAction",\n        "target": "https://www.elsotano.com/busqueda/listaLibros.php?tipoBus=full&palabrasBusqueda={search_term_string}",\n        "query-input": "required name=search_term_string"\n    }\n    }\n    </script>\n        <script src="/js/new/vendor/modernizr-2.8.3-respond-1.4.2.min.js"></script>  \n    \n<!-- Facebook Pixel Code bueno-->\n<script>\n\t!function(f,b,e,v,n,t,s)\n\t{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\tn.callMethod.apply(n,arguments):n.queue.push( ...

# %%
def quotes_parser(content):
    soup = BeautifulSoup(content,'lxml')
    quotes = soup.select("div.so-booktitle h3 a")
    author = soup.select("span.so-bookprice")
    fotos = soup.select('div.so-frontcover a[href] img[src]')
    fotos = [foto['src'] for foto in fotos]
    links=[]
    for foto in fotos:
        if foto.startswith("/"):
            foto = "https://www.elsotano.com" + foto
            links.append(foto)
    links.pop(0) #
    quotes_text= [el.text for el in quotes]
    quotoes_text= [quote.replace("\n","") for quote in quotes_text]
    author_text= [el.text for el in author]
    author_text=[author.replace("\n","") for author in author_text]
    #quote_author = zip(quotes_text,author_text) #aqui estaba links
    #quote_author=list(quote_author)
    for i in range(3):
        quotes_text.pop(0)
        author_text.pop(0)
    quote_author_links=zip(quotes_text, author_text, links)
    quote_author_links=list(quote_author_links)
    return quote_author_links



# Instantiate the IronhackSpider class
my_spider = web_scrapping_proyecto(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
# [[('CRUZIFIXUS',
#    '$183.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000334865'),
#   ('TRANSMIGRATION',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000334869'),
#   ('UNFALL MIT FOLGEN',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000334904'),
#   ('DAS WUNSCHSIEGEL',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335059'),
#   ('MOMENT OF TRUTH',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335061'),
#   ('SLAVES OF THE UNKNOWN',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335062'),
#   ('THE SEA TERROR',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335063'),
#   ('FIVE TALES OF MYSTERY AND...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335064'),
#   ('CROSSED WIRES',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335065'),
#   ('WITH DEATH YOU GET THE...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335120'),
#   ('PRIMERAS NARRACIONES',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335121'),
#   ('DIE AUFRICHTIGEN',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335319'),
#   ('WITCHES AND WIZARDS IN...',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335320'),
#   ('A HATTER GOES MAD',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335321'),
#   ('TOY SOLDIERS',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335364'),
#   ('JUSTY ONE',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335405'),
#   ('TIONG BAHRU BLUE',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335523'),
#   ('LEYENDAS DE LA MITOLOGÍA...',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335579'),
#   ('HOW TO LOSE THIGH FAT',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335598'),
#   ('LES SUGGESTIONS INFORMELLES',
#    '$228.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335599')],
#  [('HERZKIND - WUNDERKIND',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335600'),
#   ('FIRST WAVE - FANCY...',
#    '$343.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335658'),
#   ('RAGNAROK',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335691'),
#   ('WENN AUS MAMA PAPA WIRD',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335739'),
#   ('JASMIN, HERRIN DES NORDENS',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335740'),
#   ('HOW TO HYPNOTIZE ANYONE...',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335821'),
#   ('ESCRITOS DE UM OUTRO DIA',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335897'),
#   ('DEVOTE HEXE IM WALD',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335925'),
#   ('VOM LIEBESGOTT GENOMMEN',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335926'),
#   ('FRIVOLE SCHLAMPE ZU DIENSTEN',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335927'),
#   ('GYPSY',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335932'),
#   ('ASCENDING GODDESS',
#    '$137.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336182'),
#   ('HEILPRAKTIKERPRÜFUNG 840...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336194'),
#   ('EIN LEBEN NACH DEN...',
#    '$685.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336196'),
#   ('DER LETZTE BERICHT',
#    '$160.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336197'),
#   ('ZWISCHEN DEN SEITEN',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336268'),
#   ('MIT DER 60....',
#    '$160.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336269'),
#   ('DER VERHANDLUNGSMEISTER',
#    '$457.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336350'),
#   ('HOW TO TALK TO ANYONE IN...',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336352'),
#   ('HOTEL ON THE CORNER OF...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336370')],
#  [('HOROSCOPES FOR THE DEAD -...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336371'),
#   ('WIND ACROSS THE PLAYGROUND',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336379'),
#   ('EARNING FULL TIME INCOME...',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336478'),
#   ('HEALTHCARE WITH...',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336479'),
#   ('MARY',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336518'),
#   ('NEBEN DER SPUR',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336634'),
#   ('PIRATEN AUF FALSCHEM KURS',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336635'),
#   ('BAREFOOT RUNNING',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336764'),
#   ('WAN & TED - JEU DE HAINE...',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336767'),
#   ('SCORCHING SHORTS',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336921'),
#   ('AN INNOCENT AMONG THEM',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337041'),
#   ('LA SECONDA VOLTA',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337151'),
#   ('THE GOVERNESS AFFAIR',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337164'),
#   ('DAS BENEDIKTINERKLOSTER...',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337165'),
#   ('KALTER KRIEG IM SPIEGEL',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337176'),
#   ('DIE KAVALIER-G.M.B.H.',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337177'),
#   ('GETTING STARTED WITH...',
#    '$228.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337260'),
#   ('QR CODES FOR AUTHORS',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337305'),
#   ('ANTESTAMENT',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337339'),
#   ('BABY STEPS',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337467')],
#  [('DIE SIEBEN WELTWUNDER IN...',
#    '$183.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337527'),
#   ('THE NON-FICTION,...',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337529'),
#   ('AUSFLUG IN DIE ASTROLOGIE',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337641'),
#   ('DER WURM',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337652'),
#   ('EIN MORD (S) AMT',
#    '$137.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337653'),
#   ('CALABRIA- SOMMERIMPRESSIONEN',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337758'),
#   ('СЛЬНЦЕ И КАФЕ',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337759'),
#   ('MEMOIRS OF A SUPERIOR',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337826'),
#   ('FÜNF KURZGESCHICHTEN',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338573'),
#   ('DIE FÄLLE DES JAKOB...',
#    '$137.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338574'),
#   ('LEICHENTUCH: BAND 2 DER...',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338596'),
#   ('LES TEMPS CHANGENT - TOME 2',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339466'),
#   ('LES TEMPS CHANGENT - TOME 1',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339467'),
#   ('AN DER TÜR',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339641'),
#   ('AUF DEM PARKPLATZ',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339642'),
#   ('TILL DEATH',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339904'),
#   ('BONDAGE TWINS',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339905'),
#   ('THE ROYALE PROJECT',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340001'),
#   ('SOLAR STUPID',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340002'),
#   ('INSIDE THE SPHERE',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340003')],
#  [('THE ORB',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340200'),
#   ("AFFAIRS OF MEN'S HEARTS",
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340220'),
#   ('BREAKING IN OUR PET',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340224'),
#   ('RUßMITTCHEN',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340533'),
#   ('DAS AUSGEPLÜNDERTE SYSTEM',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340534'),
#   ('A TRICK OF FATE',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000340650'),
#   ('GOURMET COFFEE MUG CAKES',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338990'),
#   ('GOBLINS & VIKINGS IN...',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338991'),
#   ('GOBLINS & VIKINGS IN...',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338992'),
#   ('GOBLINS & VIKINGS IN...',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338993'),
#   ('FAIRY OF TEETH',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338994'),
#   ('A PAUNCH FULL OF PESOS',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338995'),
#   ('SEDUCED BY AN EARL',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339140'),
#   ('THE ADVENTURE TOURNAMENT',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339206'),
#   ('A LADY IN NAME',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339226'),
#   ('RETOUR À LA MAISON',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339276'),
#   ('NANEH CHINEH ET LE PETIT...',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339277'),
#   ('SPANISH IMPRESSIONS',
#    '$137.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000334793'),
#   ('ALIEN HYBRID',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000334863'),
#   ('THE CHRISTMAS CLUB',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335029')],
#  [('THE KIDNAPPING OF BILLY...',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335054'),
#   ('ABWÄRTS IN DEN TOD',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335055'),
#   ('FOG OF THE FORGOTTEN',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335056'),
#   ('QUICK PAY FOR MAVERICK MEN',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335057'),
#   ('A HOME AMONG THE STARS',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335058'),
#   ('THE OUTLAWS OF MARS',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335157'),
#   ('FITNESS AND EXERCISE FUN...',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335681'),
#   ('MAKING WAVES',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335682'),
#   ('LOS ENCANTOS DEL RÍO',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335695'),
#   ('LA MAGIA DEL RÍO',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335696'),
#   ('EYES OF THE BLIND...',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335820'),
#   ('VERSAUTE LESBEN UNTER DER...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335922'),
#   ('UNTER DER TROPENSONNE...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335923'),
#   ('DIE ÜBERFALLENDE...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335924'),
#   ('FLIGHTS OF MADNESS',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000335954'),
#   ('VENEZIANISCHE PIZZA (01)',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336091'),
#   ('BESSER REDEN UND...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336180'),
#   ('CONÓCEME',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336256'),
#   ('STONATO',
#    '$183.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336311'),
#   ('WÜSTE(N) MÄUSE',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336312')],
#  [('WALD UND FLUR. VIER...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336315'),
#   ('GRABESRACHE',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336317'),
#   ('GRABESRACHE - VAMPIR VON...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336318'),
#   ('UNSEEN',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336348'),
#   ('IN THE GARDEN OF BEASTS -...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336368'),
#   ('HOUSE RULES - BEHIND THE...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336369'),
#   ('ZAHLENTEUFEL!',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336436'),
#   ("A DOG'S PURPOSE - BEHIND...",
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336438'),
#   ('ÜBER GEORGE SMILEY',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336439'),
#   ('TAGEBUCH EINES PENDLERS',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336469'),
#   ('IST ES LYRIK? JA ICH...',
#    '$343.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336495'),
#   ('WILDE BERGORCHIDEEN',
#    '$205.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336499'),
#   ('GEDANKENSTURM',
#    '$171.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336501'),
#   ('DIE FRANZÖSISCHEN...',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336502'),
#   ('DER TODESKANDIDAT',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336514'),
#   ('VOR DEM PILZGERICHT',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336515'),
#   ('PETERSBURGER DÄMONEN',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336573'),
#   ('LEBEN UND ARBEITEN IN PANAMA',
#    '$205.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336613'),
#   ('ROULETT',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336719'),
#   ('LINDERS LISTE',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336720')],
#  [('2999 DAS DRITTE MILLENNIUM',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336721'),
#   ('STEHEN SIE DRÜBER!',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336722'),
#   ('DIE ANDERE SCHWESTER',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336723'),
#   ('TROJANISCHE PFERDE',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336724'),
#   ('AUGENSCHEIN',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336726'),
#   ('SCHAFSPELZ',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336727'),
#   ('MY DARKEST PASSION',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336763'),
#   ('DIE WAHRE GESCHICHTE VOM...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336867'),
#   ('WÖHLERS ZWEITER FALL -...',
#    '$137.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336869'),
#   ('WALLGAU',
#    '$137.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336870'),
#   ('MORD IM GEHEIMNISVOLLEN...',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336910'),
#   ('BEATRICE',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000336917'),
#   ('LUSTVOLLE ZEITEN',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337128'),
#   ('JOYFUL TIMES',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337129'),
#   ('AM LIMIT UNTER PALMEN',
#    '$343.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337145'),
#   ('NACHTANRUF',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337174'),
#   ('FRIDA KAHLO',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337254'),
#   ('BARDS AND SAGES QUARTERLY...',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337409'),
#   ('THE CURLY SITUATION',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337466'),
#   ('EIN BAYERISCHER SONDERWEG',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337471')],
#  [('SIEBEN SÜNDEN',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337495'),
#   ('DIE WEIHNACHTSKATZE',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337526'),
#   ('DARKEST DESIGNS',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337577'),
#   ("LA VENGEANCE D'UN JUIF...",
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337581'),
#   ('KOSTENFALLE HANDYTARIF',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337582'),
#   ('ZWEISTIMMIG',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337583'),
#   ('SCHULDIG',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337584'),
#   ('VAMPIRE BRAUCHEN BLUT -...',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337585'),
#   ('VAMPIRE BRAUCHEN BLUT -...',
#    '$34.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337586'),
#   ('DAS ZEITALTER ALEXANDERS...',
#    '$125.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337587'),
#   ('O AMOR DE NATHALIE',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337643'),
#   ('LOVE LOST',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337644'),
#   ('NEW RELIGION',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337645'),
#   ('SAVAGE STORM',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337647'),
#   ('HERREN DES UNIVERSUMS III',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337648'),
#   ('ELEVATOR OF DOOM',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337649'),
#   ('AZTEC, MAYA AND TOLTEC...',
#    '$80.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337650'),
#   ('EIN MORD (S) AMT',
#    '$160.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337651'),
#   ('AMACORD - GALOPP ZWISCHEN...',
#    '$148.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337732'),
#   ('BLOODY SOULS',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337754')],
#  [('EINFÜHRUNG IN DAS...',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337755'),
#   ('IRRTÜMER ÜBER UNSERE TIERE',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337756'),
#   ('VISIONES Y ESPÍRITUS DE...',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337771'),
#   ('ABENTEUER GRUBENFAHRT',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000337825'),
#   ('DER ORANGENKRIEG',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338561'),
#   ('GLÜCKSTREFFER',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338661'),
#   ('TALES FROM AFRICA',
#    '$103.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338663'),
#   ('ENTRE O CÉU E A TERRA',
#    '$91.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000338684'),
#   ('NEFILINS DEUSES',
#    '$57.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339458'),
#   ('O CONTO DE BENJAMIN BUNNY',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339459'),
#   ('O CONTO DE TOM KITTEN',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339461'),
#   ('O CONTO DE PETER RABBIT',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339462'),
#   ('OTO',
#    '$148.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339463'),
#   ('RADIOACTIVE',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339465'),
#   ('HEIMLICHES GLÜCK',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339472'),
#   ('WIE SIE MIT IMMOBILIEN...',
#    '$114.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339521'),
#   ('WEIHNACHTSZEIT MIT...',
#    '$23.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339731'),
#   ('GEMSTONE GUIDE BOOK',
#    '$45.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339790'),
#   ('THE SWORD OF IO',
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339998'),
#   ("GHOST OF WILLOW'S PAST",
#    '$68.00',
#    'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000339999')]]

# %%
x = my_spider.kickstart()
data=[]
for i in range(len(x)):
    df=pd.DataFrame(x[i])
    data.append(df)
dfc=pd.concat(data)
dfc.columns = ['Titulo', 'Precio','Link']
dfc
# Out:
#                        Titulo   Precio  \
# 0                  CRUZIFIXUS  $183.00
# 1              TRANSMIGRATION   $45.00
# 2           UNFALL MIT FOLGEN   $23.00
# 3            DAS WUNSCHSIEGEL   $91.00
# 4             MOMENT OF TRUTH   $23.00
# ..                        ...      ...
# 15  WIE SIE MIT IMMOBILIEN...  $114.00
# 16      WEIHNACHTSZEIT MIT...   $23.00
# 17        GEMSTONE GUIDE BOOK   $45.00
# 18            THE SWORD OF IO   $68.00
# 19     GHOST OF WILLOW'S PAST   $68.00
#
#                                                  Link
# 0   https://www.elsotano.com/foto/muestraPortadaEb...
# 1   https://www.elsotano.com/foto/muestraPortadaEb...
# 2   https://www.elsotano.com/foto/muestraPortadaEb...
# 3   https://www.elsotano.com/foto/muestraPortadaEb...
# 4   https://www.elsotano.com/foto/muestraPortadaEb...
# ..                                                ...
# 15  https://www.elsotano.com/foto/muestraPortadaEb...
# 16  https://www.elsotano.com/foto/muestraPortadaEb...
# 17  https://www.elsotano.com/foto/muestraPortadaEb...
# 18  https://www.elsotano.com/foto/muestraPortadaEb...
# 19  https://www.elsotano.com/foto/muestraPortadaEb...
#
# [200 rows x 3 columns]

# %%
x = my_spider.kickstart()

# %%
x[0][0]
# Out:
# 'https://www.elsotano.com/foto/muestraPortadaEbook.php?id=E1000334865'

# %%
dfc.to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\WebScrappingbooks.csv')
