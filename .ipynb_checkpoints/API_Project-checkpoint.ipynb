# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
from datetime import datetime
token= "44bbe91d452d419e9fa204215220804"
url=" http://api.weatherapi.com/v1"
url2="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Mexico&days=3"
url3="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=LA&days=3"
url4="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=NY&days=3"
url5="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=SF&days=3"
url6="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Dallas&days=3"
url7="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Seattle&days=3"
url8="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Chicago&days=3"
url9="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Denver&days=3"
url10="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Austin&days=3"
url11="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Phoenix&days=3"
url12="http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Detroit&days=3"

# %%
res = requests.get(url2)
res_jasonmex = res.json()
res_jasonmex
# Out:
# {'location': {'name': 'Mexico City',
#   'region': 'The Federal District',
#   'country': 'Mexico',
#   'lat': 19.43,
#   'lon': -99.13,
#   'tz_id': 'America/Mexico_City',
#   'localtime_epoch': 1649639132,
#   'localtime': '2022-04-10 20:05'},
#  'current': {'last_updated_epoch': 1649635200,
#   'last_updated': '2022-04-10 19:00',
#   'temp_c': 23.0,
#   'temp_f': 73.4,
#   'is_day': 0,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#    'code': 1003},
#   'wind_mph': 13.6,
#   'wind_kph': 22.0,
#   'wind_degree': 180,
#   'wind_dir': 'S',
#   'uv': 5.0},
#  'forecast': {'forecastday': [{'date': '2022-04-10',
#     'date_epoch': 1649548800,
#     'day': {'maxtemp_c': 28.3,
#      'maxtemp_f': 82.9,
#      'mintemp_c': 13.5,
#      'mintemp_f': 56.3,
#      'avgtemp_c': 19.6,
#      'avgtemp_f': 67.3,
#      'maxwind_mph': 11.4,
#      'maxwind_kph': 18.4,
#      'totalprecip_mm': 2.0,
#      'totalprecip_in': 0.08,
# ...

# %%
res_jasonmex['forecast']['forecastday'][0]['hour']
# Out:
# [{'time_epoch': 1649566800,
#   'time': '2022-04-10 00:00',
#   'temp_c': 14.8,
#   'temp_f': 58.6,
#   'is_day': 0,
#   'condition': {},
#   'wind_mph': 5.1,
#   'wind_kph': 8.3,
#   'wind_degree': 232,
#   'wind_dir': 'SW',
#   'pressure_mb': 1019.0,
#   'pressure_in': 30.08,
#   'precip_mm': 0.1,
#   'precip_in': 0.0,
#   'humidity': 53,
#   'cloud': 85,
#   'feelslike_c': 14.6,
#   'feelslike_f': 58.3,
#   'windchill_c': 14.6,
#   'windchill_f': 58.3,
#   'heatindex_c': 14.8,
#   'heatindex_f': 58.6,
#   'dewpoint_c': 5.4,
#   'dewpoint_f': 41.7,
#   'will_it_rain': 1,
#   'chance_of_rain': 89,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 7.8,
#   'gust_kph': 12.6,
#   'uv': 1.0},
#  {'time_epoch': 1649570400,
#   'time': '2022-04-10 01:00',
#   'temp_c': 14.5,
#   'temp_f': 58.1,
#   'is_day': 0,
#   'condition': {},
#   'wind_mph': 3.6,
#   'wind_kph': 5.8,
#   'wind_degree': 213,
#   'wind_dir': 'SSW',
# ...

# %%
horasmex1=pd.DataFrame(res_jasonmex['forecast']['forecastday'][0]['hour'])

# %%
horasmex2=pd.DataFrame(res_jasonmex['forecast']['forecastday'][1]['hour'])

# %%
horasmex3=pd.DataFrame(res_jasonmex['forecast']['forecastday'][2]['hour'])

# %%
horasmex= pd.concat([horasmex1,horasmex2,horasmex3])
horasmex
# Out:
#     time_epoch              time  temp_c  temp_f  is_day condition  wind_mph  \
# 0   1649566800  2022-04-10 00:00    14.8    58.6       0        {}       5.1
# 1   1649570400  2022-04-10 01:00    14.5    58.1       0        {}       3.6
# 2   1649574000  2022-04-10 02:00    14.3    57.7       0        {}       3.1
# 3   1649577600  2022-04-10 03:00    14.2    57.6       0        {}       2.9
# 4   1649581200  2022-04-10 04:00    14.0    57.2       0        {}       2.2
# ..         ...               ...     ...     ...     ...       ...       ...
# 19  1649808000  2022-04-12 19:00    25.5    77.9       1        {}       8.9
# 20  1649811600  2022-04-12 20:00    24.1    75.4       0        {}       9.4
# 21  1649815200  2022-04-12 21:00    23.1    73.6       0        {}       7.8
# 22  1649818800  2022-04-12 22:00    22.3    72.1       0        {}       5.8
# 23  1649822400  2022-04-12 23:00    21.8    71.2       0        {}       4.9
#
# ...

# %%
url_lista = ["http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=LA&days=3",
             "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=NY&days=3",
             "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=SF&days=3",
             "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Dallas&days=3",
            "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Seattle&days=3",
            "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Chicago&days=3",
            "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Denver&days=3",
            "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Austin&days=3",
            "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Phoenix&days=3",
            "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Detroit&days=3",
             "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Philadelphia&days=3",
             "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Pittsburgh&days=3",
             "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Baltimore&days=3",
             "http://api.weatherapi.com/v1/forecast.json?key=44bbe91d452d419e9fa204215220804&q=Mexico&days=3"]



horas_url_list=[]
horas_concat=[]
for i in range(len(url_lista)):
    res = requests.get(url_lista[i])
    res_url = res.json()
    for j in range(3):
        horas_url_list.append(pd.DataFrame(res_url['forecast']['forecastday'][j]['hour']))
    x = 3*i
    y = x+1
    z = x+2
    horas_concat.append(pd.concat([horas_url_list[x],horas_url_list[y],horas_url_list[z]])) 
    time.sleep(10)

# %%
horas_concat[13]
# Out:
#     time_epoch              time  temp_c  temp_f  is_day condition  wind_mph  \
# 0   1649566800  2022-04-10 00:00    14.8    58.6       0        {}       5.1
# 1   1649570400  2022-04-10 01:00    14.5    58.1       0        {}       3.6
# 2   1649574000  2022-04-10 02:00    14.3    57.7       0        {}       3.1
# 3   1649577600  2022-04-10 03:00    14.2    57.6       0        {}       2.9
# 4   1649581200  2022-04-10 04:00    14.0    57.2       0        {}       2.2
# ..         ...               ...     ...     ...     ...       ...       ...
# 19  1649808000  2022-04-12 19:00    25.5    77.9       1        {}       8.9
# 20  1649811600  2022-04-12 20:00    24.1    75.4       0        {}       9.4
# 21  1649815200  2022-04-12 21:00    23.1    73.6       0        {}       7.8
# 22  1649818800  2022-04-12 22:00    22.3    72.1       0        {}       5.8
# 23  1649822400  2022-04-12 23:00    21.8    71.2       0        {}       4.9
#
# ...

# %%
horas_concat[0].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\LA_Clima.csv')
horas_concat[1].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\NY_Clima.csv')
horas_concat[2].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\SF_Clima.csv')
horas_concat[3].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Dallas_Clima.csv')
horas_concat[4].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Seattle_Clima.csv')
horas_concat[5].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Chicago_Clima.csv')
horas_concat[6].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Denver_Clima.csv')
horas_concat[7].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Austin_Clima.csv')
horas_concat[8].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Phoenix_Clima.csv')
horas_concat[9].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Detroit_Clima.csv')
horas_concat[10].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Philadelphia_Clima.csv')
horas_concat[11].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Pittsburgh_Clima.csv')
horas_concat[12].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Baltimore_Clima.csv')
horas_concat[13].to_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Proyecto2\Climas_Ciudades_API\Mexico_Clima.csv')
